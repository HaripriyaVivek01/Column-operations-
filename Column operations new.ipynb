# %%
import pandas as pd

# %%
market_fact=pd.read_csv('C:/Users/LENOVO/Downloads/market_fact.csv')

# %%
market_fact
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market_fact['Actual_sales']=market_fact['Sales']+market_fact['Discount']

# %%
market_fact
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market_fact['Unit_cost']=market_fact['Sales']/market_fact['Order_Quantity']

# %%
market_fact
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market_fact.rename(columns={'Sales':'Sales_Amount'})
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id  Sales_Amount  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818      136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818       42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818     4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818     2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818     4233.1500      0.08
# ...        ...      ...       ...        ...           ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798     2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798      127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798      243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798     3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798      603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
market_fact.rename(columns={'Ord_id':'Order_id','Prod_id':'Product_id','Ship_id':'Shipping_id','Cust_id':'Customer_id'})
# Out:
#       Order_id Product_id Shipping_id Customer_id      Sales  Discount  \
# 0     Ord_5446    Prod_16    SHP_7609   Cust_1818   136.8100      0.01
# 1     Ord_5406    Prod_13    SHP_7549   Cust_1818    42.2700      0.01
# 2     Ord_5446     Prod_4    SHP_7610   Cust_1818  4701.6900      0.00
# 3     Ord_5456     Prod_6    SHP_7625   Cust_1818  2337.8900      0.09
# 4     Ord_5485    Prod_17    SHP_7664   Cust_1818  4233.1500      0.08
# ...        ...        ...         ...         ...        ...       ...
# 8394  Ord_5353     Prod_4    SHP_7479   Cust_1798  2841.4395      0.08
# 8395  Ord_5411     Prod_6    SHP_7555   Cust_1798   127.1600      0.10
# 8396  Ord_5388     Prod_6    SHP_7524   Cust_1798   243.0500      0.02
# 8397  Ord_5348    Prod_15    SHP_7469   Cust_1798  3872.8700      0.03
# 8398  Ord_5459     Prod_6    SHP_7628   Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# ...

# %%
market_fact.drop(['Actual_sales'],axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin   Unit_cost
# 0                 23   -30.51           3.60                 0.56    5.948261
# ...

# %%
market_fact.drop(['Product_Base_Margin', 'Unit_cost'],axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Actual_sales
# 0                 23   -30.51           3.60      136.8200
# ...

# %%
market_fact.columns=[col.upper()for col in market_fact.columns]

# %%
market_fact.columns
# Out:
# Index(['ORD_ID', 'PROD_ID', 'SHIP_ID', 'CUST_ID', 'SALES', 'DISCOUNT',
#        'ORDER_QUANTITY', 'PROFIT', 'SHIPPING_COST', 'PRODUCT_BASE_MARGIN',
#        'ACTUAL_SALES', 'UNIT_COST'],
#       dtype='object')

# %%
market_fact.columns=[col.lower()for col in market_fact.columns]

# %%
market_fact.columns
# Out:
# Index(['ord_id', 'prod_id', 'ship_id', 'cust_id', 'sales', 'discount',
#        'order_quantity', 'profit', 'shipping_cost', 'product_base_margin',
#        'actual_sales', 'unit_cost'],
#       dtype='object')

# %%
market_fact.sort_values(by='Cust_id', ascending=True)
# Out:
#         Ord_id  Prod_id   Ship_id   Cust_id     Sales  Discount  \
# 5858     Ord_1   Prod_1     SHP_1    Cust_1   261.540      0.04
# 1770    Ord_10   Prod_3    SHP_13   Cust_10    80.610      0.02
# 1507   Ord_271   Prod_5   SHP_369  Cust_100  2522.210      0.00
# 1506   Ord_271  Prod_17   SHP_370  Cust_100  4181.820      0.01
# 1505   Ord_227   Prod_7   SHP_315  Cust_100   181.780      0.02
# ...        ...      ...       ...       ...       ...       ...
# 7053  Ord_2612   Prod_6  SHP_3574  Cust_999   193.160      0.03
# 7054  Ord_2588   Prod_2  SHP_3543  Cust_999   508.730      0.08
# 7055  Ord_2685   Prod_4  SHP_3676  Cust_999   617.219      0.03
# 7048  Ord_2827   Prod_6  SHP_3889  Cust_999   614.910      0.02
# 7040  Ord_2668   Prod_2  SHP_3654  Cust_999    78.790      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 5858               6  -213.25          35.00                 0.80
# ...

# %%
market_fact.sort_values(by=['Sales','Profit'], ascending=[True,False])
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# ...        ...      ...       ...        ...       ...       ...
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 6700               1     -1.97           0.70                 0.37
# ...

# %%
market_fact.drop('Product_Base_Margin',axis=1, inplace=True)

# %%
market_fact
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost
# 0                 23   -30.51           3.60
# 1                 13     4.56           0.93
# ...

# %%
market_fact.groupby('Cust_id').count()
# Out:
#            Ord_id  Prod_id  Ship_id  Sales  Discount  Order_Quantity  Profit  \
# Cust_id
# Cust_1          1        1        1      1         1               1       1
# Cust_10         1        1        1      1         1               1       1
# Cust_100        6        6        6      6         6               6       6
# Cust_1000       7        7        7      7         7               7       7
# Cust_1001      10       10       10     10        10              10      10
# ...           ...      ...      ...    ...       ...             ...     ...
# Cust_995       12       12       12     12        12              12      12
# Cust_996        5        5        5      5         5               5       5
# Cust_997       10       10       10     10        10              10      10
# Cust_998        4        4        4      4         4               4       4
# Cust_999       20       20       20     20        20              20      20
#
#            Shipping_Cost
# Cust_id
# ...

# %%
print(market_fact['Ord_id'].isnull().sum())
# Out:
# 0

# %%
print(len(market_fact.columns.values))
# Out:
# 9

# %%
print(market_fact.columns.values)
# Out:
# ['Ord_id' 'Prod_id' 'Ship_id' 'Cust_id' 'Sales' 'Discount'
#  'Order_Quantity' 'Profit' 'Shipping_Cost']
